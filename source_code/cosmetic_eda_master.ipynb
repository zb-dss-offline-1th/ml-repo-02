# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Modules-&amp;-Functions" data-toc-modified-id="Modules-&amp;-Functions-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Modules &amp; Functions</a></span></li></ul></li><li><span><a href="#Domain-Knoweldge" data-toc-modified-id="Domain-Knoweldge-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Domain Knoweldge</a></span></li><li><span><a href="#'제품명-주성분'-데이터" data-toc-modified-id="'제품명-주성분'-데이터-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>'제품명-주성분' 데이터</a></span><ul class="toc-item"><li><span><a href="#데이터" data-toc-modified-id="데이터-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>데이터</a></span></li><li><span><a href="#이상치-및-결측치-확인" data-toc-modified-id="이상치-및-결측치-확인-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>이상치 및 결측치 확인</a></span></li></ul></li><li><span><a href="#'제품명-주성분'-데이터를-활용한-각-성분의-활용-빈도-분석" data-toc-modified-id="'제품명-주성분'-데이터를-활용한-각-성분의-활용-빈도-분석-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>'제품명-주성분' 데이터를 활용한 각 성분의 활용 빈도 분석</a></span><ul class="toc-item"><li><span><a href="#데이터-재확인" data-toc-modified-id="데이터-재확인-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>데이터 재확인</a></span></li><li><span><a href="#성분별-포함된-제품-수-계수" data-toc-modified-id="성분별-포함된-제품-수-계수-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>성분별 포함된 제품 수 계수</a></span></li><li><span><a href="#데이터-시각화" data-toc-modified-id="데이터-시각화-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>데이터 시각화</a></span><ul class="toc-item"><li><span><a href="#상위-1-%-데이터-(사용된-제품수-기준)-제외" data-toc-modified-id="상위-1-%-데이터-(사용된-제품수-기준)-제외-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>상위 1 % 데이터 (사용된 제품수 기준) 제외</a></span></li></ul></li></ul></li><li><span><a href="#'성분-효능'-데이터와-'제품명-주성분'-데이터에서-확보한-성분별-활용도-교차-분석" data-toc-modified-id="'성분-효능'-데이터와-'제품명-주성분'-데이터에서-확보한-성분별-활용도-교차-분석-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>'성분-효능' 데이터와 '제품명-주성분' 데이터에서 확보한 성분별 활용도 교차 분석</a></span><ul class="toc-item"><li><span><a href="#'성분-효능(목록)'-데이터" data-toc-modified-id="'성분-효능(목록)'-데이터-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>'성분-효능(목록)' 데이터</a></span><ul class="toc-item"><li><span><a href="#중복데이터-확인-및-처리" data-toc-modified-id="중복데이터-확인-및-처리-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>중복데이터 확인 및 처리</a></span></li></ul></li><li><span><a href="#'성분-계-효능'-데이터" data-toc-modified-id="'성분-계-효능'-데이터-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>'성분-계-효능' 데이터</a></span><ul class="toc-item"><li><span><a href="#'성분별-활용-횟수/비율'-데이터-(활용-수-기준-내림차순-정렬)에-'성분-효능'-데이터-병합" data-toc-modified-id="'성분별-활용-횟수/비율'-데이터-(활용-수-기준-내림차순-정렬)에-'성분-효능'-데이터-병합-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>'성분별 활용 횟수/비율' 데이터 (활용 수 기준 내림차순 정렬)에 '성분-효능' 데이터 병합</a></span></li><li><span><a href="#성분별-효능목록-0번째-나열된-효능을-'주효능'으로-구분" data-toc-modified-id="성분별-효능목록-0번째-나열된-효능을-'주효능'으로-구분-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>성분별 효능목록 0번째 나열된 효능을 '주효능'으로 구분</a></span></li><li><span><a href="#'성분-계-효능(목록)'-데이터와-'성분-주효능'-데이터-병합" data-toc-modified-id="'성분-계-효능(목록)'-데이터와-'성분-주효능'-데이터-병합-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>'성분-계-효능(목록)' 데이터와 '성분-주효능' 데이터 병합</a></span></li><li><span><a href="#'효능-성분'-데이터-(전체-효능/중복-허용)" data-toc-modified-id="'효능-성분'-데이터-(전체-효능/중복-허용)-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>'효능-성분' 데이터 (전체 효능/중복 허용)</a></span></li></ul></li><li><span><a href="#최종-데이터-확인" data-toc-modified-id="최종-데이터-확인-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>최종 데이터 확인</a></span></li><li><span><a href="#데이터-시각화" data-toc-modified-id="데이터-시각화-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>데이터 시각화</a></span><ul class="toc-item"><li><span><a href="#Save-File:-'skca_ing_count_effect.csv'" data-toc-modified-id="Save-File:-'skca_ing_count_effect.csv'-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Save File: 'skca_ing_count_effect.csv'</a></span></li></ul></li></ul></li><li><span><a href="#제품별-포함된-성분-WORDCLOUD" data-toc-modified-id="제품별-포함된-성분-WORDCLOUD-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>제품별 포함된 성분 WORDCLOUD</a></span></li></ul></div>

# %% [markdown]
# # Cosmetics Product & Ingredient Data - EDA

# %% [markdown]
# ### Modules & Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
from tqdm import tqdm_notebook
from collections import defaultdict
import operator

# %% [markdown]
# ## Domain Knoweldge

# %% [markdown]
# **[ 부형제 ]**
# - 화장품의 대부분을 차지하는 유탁액을 만드는데 사용하는 물질
# - 유탁액은 피부 보호막과 유사한 성분으로 만들에 지며, 수분, 유분, 유화제를 혼합하여 만든다.<br>
# ex) 유탁액에 사용되는 수분에는 물과 식물 추출물의 수용성 물질이 사용되며, 유분에는 오일, 왁스, 아보카도 오일 등이 사용 됨
#
# **[ 활성 성분 ]**
# - 화장품에 특별한 효능을 부여하기 위해 사용하는 물질. 각 제품의 특징을 나타내는 역할을 함<br>
# ex) 수분크림 안에 보습작용을 하는 물질, 선크림에 사용되는 자외선을 차단하는 성분, 비타민 앰플에 사용되는 비타민 추출액 등
#
# **[ 첨가제 ]**
# - 화장품의 화학반응이나 세균에 의해 부패되는 것을 막고 안정 된 상태로 유지하기 위해 첨가하는 성분<br>
# ex) 보존제, 산화방지제 등
#
# **[ 착향제 ]**
# - 화장품에서 좋은 향이 나도록 돕는 향료

# %% [markdown]
# |칼럼명|뜻|역할|
# |--|--|--|
# |'abrasive/scrub' | 연마제/스크럽 | 피부를 윤기나게 하거나 각질을 제거하는 데 도움이 되는 스크럽의 작은 "덩어리" 성분. 연마제는 또한 치아를 청소하기 위해 구강 관리 제품에 자주 사용됩니다.|
# |'anti-acne'| 항여드름 | 여드름 퇴치에 도움이 되는 좋은 성분. 그들은 또한 종종 항균제 및/또는 항염증제입니다.|
# |'antimicrobial/antibacterial'| 향균(미생물 포함) | 피부의 미생물 성장을 조절하는 성분. 항균제는 박테리아의 성장 또는 번식을 제어하는 ​​반면 항균제는 더 넓은 범위에서 박테리아, 곰팡이 및 일부 바이러스의 확산을 방지합니다.|
# |'antioxidant'|항산화제|피부가 콜라겐을 손상시키는 free radical* 을 퇴치하는 데 도움이 되는 좋은 성분. 이 기능이 포함된 성분은 중요한 노화 방지 성분 중 하나입니다.|
# |'buffering'|완충제|화장품 포뮬러의 pH를 적정한 값으로 설정해주는 헬퍼 성분.|
# |'cell-communicating ingredient'|세포-전달 성분|피부 세포에 "더 잘 행동"하도록 신호를 보내는 성분. 가장 유명한 예는 레티놀 또는 펩타이드입니다.|
# |'chelating'|킬레이트제|금속 이온(보통 물에서 유래)과 반응하여 공식을 안정적으로 유지하는 데 도움이 되는 도우미 성분|
# |'colorant'|착색제|화장품에 좋은 색상을 부여하는 보조 성분입니다.|
# |'emollient'|피부연화제|피부를 부드럽고 매끄럽고 사랑스럽게 만드는 좋은 성분.|
# |'emulsifying'|유화제|일반적으로 서로 섞이는 것을 좋아하지 않는 성분(특히 물과 기름)들이 훌륭하고 균일한 혼합물을 형성하도록 돕는 성분. 그것들이 없으면 화장품이 물기 부분과 기름기 부분으로 분리됩니다.|
# |'exfoliant'|각질제거제|각질 제거에 도움을 주는 좋은 성분들이 피부를 더욱 신선하고 매끄럽게 가꾸어 줍니다. 그것들 중 많은 성분들이 피부에 추가적인 이점을 가지고 있습니다.|
# |'moisturizer/humectant'|보습제/습윤제|습윤제(Humectant)는 피부가 물에 잘 달라붙어 피부가 촉촉한 느낌이 들도록 도와주는 모이스처라이저 성분의 정식 명칭입니다.|
# |'perfuming'|향수|좋은 냄새가 나도록 합니다.|
# |'preservative'|방부제|화장품이 음식처럼 작동하지 않도록 도와주는 것: 냉장고에 넣어두어도 1~2주 안에 상하는 것처럼. 그들은 일반적으로 가장 피부 친화적인 성분은 아니지만 매우 중요하고 이것이 없으면 화장품 안전을 위협하고 완전히 안전한 수준으로 소량을 사용합니다.|
# |'skin brightening'|피부 미백제|태양 손상 또는 PIH(염증 후 색소 침착)로 인한 갈색 반점(과색소 침착)을 완화시키는 데 도움이 되는 성분.|
# |'skin-identical ingredient'|피부유사성분|피부에서 찾을 수 있거나 피부에서 자연적으로 찾을 수 있는 것을 모방하는 정말 좋은 성분. 그들은 두 개의 큰 그룹*이 있습니다.|
# |'solvent'|용제|제품의 다른 성분을 녹이는 성분. 가장 큰 비중을 차지하는 물이 여기 해당됨.|
# |'soothing'|진정제|CosIng*의 공식 정의는 "피부의 불편함을 완화시키는 데 도움이 되는 성분". 염증을 줄이고 피부를 진정시키는 좋은 항염 및 항자극 성분이 이 범주에 속합니다. 그들은 일반적으로 피부의 노화 과정을 늦추는 데 도움이 되며 여드름, 주사비 또는 민감한 피부와 같은 몇 가지 일반적인 피부 질환에 매우 도움이 됩니다.|
# |'sunscreen'|자외선 차단제|자외선으로부터 피부를 보호하는 데 도움이 되는 성분.|
# |'surfactant/cleansing'|계면활성제/세정제|화장품의 표면장력을 낮추고 제품이 고르고 쉽게 퍼질 수 있도록 도와주는 성분. 그들은 일반적으로 물을 좋아하는 머리 부분과 기름을 좋아하는 꼬리 부분을 가지고 있으므로 클렌저 또는 거품을 만드는 모든 것의 중요한 성분이 되는 경향이 있습니다. 종종 계면활성제는 세정 및 유화 성분이기도 합니다.|
# |'viscosity controlling'|점도 조절제|이것이 증점제의 공식 기능 이름입니다. 이들은 제품을 thicken-up 하여 질감이 좋은 젤, 세럼 또는 모이스처라이저를 형성하는 데 도움이 되는 성분입니다.|
#
#
# 정확히 21개의 기능을 확인할 수 있었습니다.
# <br>
# *Fragrance란 항목이 있는데, 이 기능을 포함한 성분이 존재하지 않습니다. 따라서 고려할 필요는 없을 듯 합니다.
# <br>
# <br>
# free radical: 동식물의 체내 세포들의 대사과정에서 생성되는 산소화합물인 활성산소를 이르는 말이다. 활성산소는 체내 적당량이 있으면 세균이나 이물질로부터 방어하는 기능을 하지만, 과다 발생할 경우 정상세포까지 무차별 공격해 각종 질병과 노화의 주원인이 된다.
# <br>
# <br>
# NMFs(Natural Moisturizing Factor): 각질형성세포(피부 세포) 내부에서 발견될 수 있고 우리 피부가 물을 붙잡아두는 데 도움이 되는 것들. 글리세린 또는 히알루론산은 유명한 NMF입니다. 그들은 피부의 수분을 잘 유지하는 데 매우 중요합니다.
# <br>
# <br>
# SC(각질층 - 피부의 외부 층) 지질: 피부 세포 사이에는 세포외 기질이라고 하는 끈적끈적한 물질이 있습니다. 그것은 주로 지질로 구성되어 있으며 건강한 피부 장벽을 갖는 데 매우 중요합니다. 세라마이드, 콜레스테롤 및 지방산은 중요한 SC 지질입니다.
# <br>
# <br>
# CosIng: EU의 화장품 원료 정보 데이터베이스

# %% [markdown]
# ## '제품명-주성분' 데이터
#
# **FINDINGS & REMARKS** :<br>
#
# 1. <big>제품 데이터 77,000 개</big><br>
#
#     ***[주의!]*** info()로 1차 확인시 결측치가 없음.<br>
#     &rarr; 이는 성분정보가 없어도 텍스트 데이터('[]')로 존재하기 때문일 것임.<br>
#     &rarr; 각 주성분 리스트 (텍스트 데이터)를 실제 리스트 타입의 데이터로 변환하여 주성분 목록읙 길이 확인 필요.<br>
#
# 2. 주성분 리스트 길이 확인을 통한 <big>결측치 확인</big> (주성분이 3개 미만인 제품도 있는지 추가 확인)
#
#     |주성분 수(x)|주성분 수 가 x개인 제품 수|제품 예시|제품 URL 링크|
#     |---|---|---|---|
#     |0개|없음|-|-|
#     |1개|<span style="color:red">181</span>|Almond Oil|https://incidecoder.com/products/action-almond-oil|
#     |2개|<span style="color:red">145</span>|Original Oil|https://incidecoder.com/products/abyssian-original-oil|
#     |3개|234|Primer And Set Powder|https://incidecoder.com/products/14e-cosmetics-primer-and-set-powder|
#
#
#     &rarr; 제품 주성분이 존재하지 않는(주성분 수=0) 결측치 없음.<br>
#
#     &rarr; 제품 주성분이 1~2개 인 제품 확인됨(예: Almond Oil, Original Oil=오일 2종 합성 제품)<br>
#     &rarr; 화장품으로 정의하기에 부적합하여 이상치로 구분할 수도 있음. 추후 EDA 과정 후반에서 필요시 처리하도록 하고 우선 *데이터 유지 결정*

# %% [markdown]
# ### 데이터

# %%
inci_prod = pd.read_csv('inci_prod_final.csv')
inci_prod.head()
# Out:
#                                         product name  \
# 0          001-skincare-active-marine-collagen-serum
# 1  001-skincare-alpha-glow-flash-facial-serum-pri...
# 2          001-skincare-alpha-paradise-cleansing-dew
# 3     001-skincare-amino-acids-lipids-recovery-cream
# 4     001-skincare-beighten-plump-emulsion-clay-mask
#
#                                          ingredients  \
# 0  ['Aqua', 'Aloe Barbadensis Leaf Extract', 'Pol...
# 1  ['Aqua', 'Rosa Damascena Flower Water', 'Aloe ...
# 2  ['Prunus Amygdalus Dulcis Oil (Sweet Almond)',...
# 3  ['Aqua', 'Helianthus Annuus Seed Oil*', 'Butyr...
# 4  ['Aqua', 'Kaolin', 'Glycerin', 'Bentonite', 'P...
#
#                                formatted ingredients
# 0  ['water', 'aloe-barbadensis-leaf-extract', 'po...
# 1  ['water', 'rosa-damascena-flower-water', 'aloe...
# 2  ['prunus-amygdalus-dulcis-oil', 'simmondsia-ch...
# 3  ['water', 'helianthus-annuus-seed-oil', 'butyr...
# 4  ['water', 'kaolin', 'glycerin', 'bentonite', '...

# %%
# 데이터 1차 확인
inci_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77000 entries, 0 to 76999
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product name           77000 non-null  object
#  1   ingredients            77000 non-null  object
#  2   formatted ingredients  77000 non-null  object
# dtypes: object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# ### 이상치 및 결측치 확인

# %%
# 함수 설명: 주성분 목록의 길이가 x(length)개인 제품들의 수 계산
def find_inglst_length(length):
    products = []
    for i,data in enumerate(inci_prod['formatted ingredients']):
        data = data.split("'")
        tmp = []
        for each in data:
            if len(each) != 1:
                if ',' not in each:
                    tmp.append(each)
        if len(tmp) == length:
            products.append(inci_prod['product name'][i])

    return products

# %%
# 주성분 목록의 길이가 0~3개인 제품의 갯수 확인
for i in range(4):
    check  = find_inglst_length(i)
    print(f'Number of products with {i} ingredient:', len(check))
# Out:
# Number of products with 0 ingredient: 0
# Number of products with 1 ingredient: 181
# Number of products with 2 ingredient: 145
# Number of products with 3 ingredient: 234

# %%
# 주성분이 1~3개인 제품들 직접 확인
for i in range(1,4):
    print(f'주성분{i}개 제품 예시: {find_inglst_length(i)[0]}')
    print('url: '+'https://incidecoder.com/products/'+str(find_inglst_length(i)[0]))
# Out:
# 주성분1개 제품 예시: action-almond-oil
# url: https://incidecoder.com/products/action-almond-oil
# 주성분2개 제품 예시: abyssian-original-oil
# url: https://incidecoder.com/products/abyssian-original-oil
# 주성분3개 제품 예시: 14e-cosmetics-primer-and-set-powder
# url: https://incidecoder.com/products/14e-cosmetics-primer-and-set-powder

# %% [markdown]
# ## '제품명-주성분' 데이터를 활용한 각 성분의 활용 빈도 분석
#
# **FINDINGS & REMARKS** :<br>
#
# 1. 77,000개의 unique한 제품의 주성분 목록에 존재하는 <big>성분을 각각 계수</big><br><br>
#    ***[ 주의! ]*** 'formatted ingredients' 컬럼의 성분 데이터를 사용<br>
#    &rarr; 이유 : 'ingreidients' 컬럼의 데이터는 육안으로도 성분의 표기 방식이 일정하지 않음이 확인됨 (관련 처리는 추후 진행)
# <br>
#
# 1. <big>사용된 성분 종류 (unique): 15,186개</big>
# <br>
#
# 3. <big>활용도 TOP 5 성분:</big>
#
#    |순위|성분명|포함된 제품 수|전체 제품 수 대비 활용도(%)|
#    |---|---|---|---|
#    |1|water|67,796|88.05|
#    |2|glycerin|55,954|72.67|
#    |3|phenoxyethanol|36,755|47.73|
#    |4|parfum|36,094|46.88|
#    |5|butylene-glycol|24,942|32.39|
# <br>
#
# 4. 성분별 활용 빈도(수치형) 데이터 <big>기초통계량</big> 확인
#
#    ||포함된 제품 수|전체 제품 수 대비 활용도(%)|
#    |---|---|---|
#    |평균|134|0.17|
#    |표준편차|1173|1.52|
#    |최솟값|1|0.00|
#    |최댓값|66,796|88.05|
#    |25%(Q1)|1|0.00|
#    |50%(Q2)|4|0.01|
#    |75%(Q3)|24|0.03|
#
#    &rarr; 포함된 제품 수 기준, <big>상위 1% (152개) 데이터 제거</big> 시<br>
#       ||포함된 제품 수|전체 제품 수 대비 활용도(%)|
#       |---|---|---|
#       |평균|59|0.076|
#       |표준편차|204|0.26|
#       |최댓값|2,377|3.09|
#       |75%(Q3)|22|0.03|
#
#    <br>
#
#    <big> &rarr; 다수의 제품에 공통으로 포함된 성분은 유사도 측정에 영향 예상. 이상치 처리가 필요할 것으로 보임.<br></big>
#    <big>&rarr; **단, 사전에 추가적인 특성 확인이 필요 (해당 성분의 효능/용도)** <br></big>

# %% [markdown]
# ### 데이터 재확인

# %%
inci_prod
# Out:
#                                             product name  \
# 0              001-skincare-active-marine-collagen-serum
# 1      001-skincare-alpha-glow-flash-facial-serum-pri...
# 2              001-skincare-alpha-paradise-cleansing-dew
# 3         001-skincare-amino-acids-lipids-recovery-cream
# 4         001-skincare-beighten-plump-emulsion-clay-mask
# ...                                                  ...
# 76995            zymogen-fermented-soybean-firming-serum
# 76996            zymogen-houttuynia-cordata-ferment-mist
# 76997           zymogen-houttuynia-cordata-ferment-serum
# 76998               zymogen-long-lasting-power-sun-cream
# 76999                 zyu-complexion-perfector-spf-50-pa
#
#                                              ingredients  \
# 0      ['Aqua', 'Aloe Barbadensis Leaf Extract', 'Pol...
# 1      ['Aqua', 'Rosa Damascena Flower Water', 'Aloe ...
# 2      ['Prunus Amygdalus Dulcis Oil (Sweet Almond)',...
# ...

# %% [markdown]
# ### 성분별 포함된 제품 수 계수

# %%
# 'item_count' 딕셔너리에 각 제품에 들어있는 성분 누적 총계
item_count = defaultdict(int)
for i,each_ing in enumerate(inci_prod['formatted ingredients']): 

    # 성분들 이름만 가져오는 전처리 작업
    each = each_ing.split("'")
    tmp = []
    for e in each:
        if len(e) != 1:
            if ',' not in e:
                tmp.append(e)
    for item in tmp:
        item_count[item] += 1

# 'item_count' 딕셔너리를 성분별 계(=딕셔너리의 value) 기준으로 내림차순 정렬
item_count = sorted(item_count.items(), key=operator.itemgetter(1),reverse=True)

# 'item_count' 딕셔너리를 'ing_count'라는 이름의 df로 변환하고 컬럼명 조정
ing_count = pd.DataFrame.from_dict(item_count)
ing_count.rename(columns={0:'ingredient',1:'count'},inplace=True)

# 전체 제품 데이터 수 대비 활용 비율 (%)
ing_count['used %'] = round(ing_count['count']/len(inci_prod['product name'])*100,2)

print('TOP 10 ingredients, used count & used %: ')
ing_count[:10]
# Out:
# TOP 10 ingredients, used count & used %:
#            ingredient  count  used %
# 0               water  67796   88.05
# 1            glycerin  55954   72.67
# 2      phenoxyethanol  36755   47.73
# 3              parfum  36094   46.88
# 4     butylene-glycol  24942   32.39
# 5  ethylhexylglycerin  23514   30.54
# 6       disodium-edta  22870   29.70
# 7         citric-acid  22393   29.08
# 8         xanthan-gum  22376   29.06
# 9          tocopherol  22333   29.00

# %%
# 기초 통계량 1차 확인
ing_count.describe()
# Out:
#               count        used %
# count  15186.000000  15186.000000
# mean     134.455749      0.174044
# std     1173.184923      1.523711
# min        1.000000      0.000000
# 25%        1.000000      0.000000
# 50%        4.000000      0.010000
# 75%       24.000000      0.030000
# max    67796.000000     88.050000

# %% [markdown]
# ### 데이터 시각화

# %%
# distribution plot (used %)
plt.rcParams['figure.figsize'] = [10, 5]
fig = plt.figure(1)
dist=sns.distplot(ing_count['used %'])
dist.set(title="Distribution of Each Ingredient's Used %")
plt.show()
# Out:
# C:\Users\jihyu\miniconda3\envs\ds_study\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution plot (count)
plt.rcParams['figure.figsize'] = [10, 5]
fig = plt.figure(1)
dist=sns.distplot(ing_count['count'])
dist.set(title="Distribution of Each Ingredient's Used Count")
plt.show()
# Out:
# C:\Users\jihyu\miniconda3\envs\ds_study\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 상위 1 % 데이터 (사용된 제품수 기준) 제외
# 총 152개 데이터 제거

# %%
# Set cut_point (Top 99%)
cut_point = ing_count['count'].quantile(0.99)
ing_count_cut= ing_count[ing_count['count'] < cut_point]
print('Number of Ingredients Eliminated : ', len(ing_count['ingredient']) - len(ing_count_cut['ingredient']))
ing_count_cut.describe()
# Out:
# Number of Ingredients Eliminated :  152
#               count        used %
# count  15034.000000  15034.000000
# mean      59.564653      0.076777
# std      204.624029      0.265961
# min        1.000000      0.000000
# 25%        1.000000      0.000000
# 50%        4.000000      0.010000
# 75%       22.000000      0.030000
# max     2377.000000      3.090000

# %%
ing_count_cut[:10]
# Out:
#                                      ingredient  count  used %
# 152  dimethicone-vinyl-dimethicone-crosspolymer   2377    3.09
# 153                                    ci-77499   2374    3.08
# 154                                ceteareth-20   2370    3.08
# 155                                    coumarin   2363    3.07
# 156                                 cholesterol   2340    3.04
# 157                   sodium-ascorbyl-phosphate   2333    3.03
# 158                                     glucose   2331    3.03
# 159                     triethoxycaprylylsilane   2275    2.95
# 160                   potassium-cetyl-phosphate   2246    2.92
# 161                          aluminum-hydroxide   2242    2.91

# %%
# Quick Histogram Check
plt.figure(figsize=(10,5))
ing_count_cut['count'].hist()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig = plt.figure(1)
box = sns.boxplot(x='count',palette='GnBu',data = ing_count_cut)
box.set_title('Ingredient Used Count - Boxplot')
plt.show()

# %%
# catplot(boxen) - ing_count_cut
plt.rcParams['figure.figsize'] = [10,5]
fig = plt.figure(1)
sns.catplot(x='count', kind='boxen',palette='GnBu',data=ing_count_cut)
plt.show()

# %% [markdown]
# (성분별 사용된 제품수 기준) 상위 1% (152개) 데이터를 제거 후 재관찰 결과 2,000개 이상의 제품에서 사용된 성분의 경우 이상치로 판단

# %% [markdown]
# ## '성분-효능' 데이터와 '제품명-주성분' 데이터에서 확보한 성분별 활용도 교차 분석
#
#
# **FINDINGS & REMARKS** :<br>
#
# 1. 성분 데이터 15,186개 확보 (제품명-주성분 데이터와 동일)<br>
#
#     최초 72,691개 성분 데이터 중 중복데이터 확인<br>
#     &rarr; **원인**: 'ingredient' 컬럼에 같은 성분이 다른 방식으로 표기됨 (예: water: 'Water','Aqua','Aqua(Water)',etc)<br>
#     &rarr; **처리**: 'formatted ingredients' 컬럼의 데이터를 기준으로 중복데이터 제거
#
# 2. 효능정보 ('what-it-does') 목록이 텍스트데이터로 존재하여 결측치가 확인되지 않음
#     &rarr; 각 성분의 효능정보(텍스트 데이터)를 리스트 타입의 데이터로 변환 필요
#
# 3. 효능 표기 성분 5,298개(전체 데이터 33%) <br>
#    &rarr; 효능 표기 누락 성분: **10,518개**
#    <br>
#
# 4. 활용도 TOP 5 성분 (주효능 포함):
#
#    |순위|성분명|포함된 제품 수|전체 제품 수 대비 활용도(%)|주효능|
#    |---|---|---|---|---|
#    |1|water|67,796|88.05|solvent|
#    |2|glycerin|55,954|72.67|skin-identical ingredient|
#    |3|phenoxyethanol|36,755|47.73|preservative|
#    |4|parfum|36,094|46.88|perfuming|
#    |5|butylene-glycol|24,942|32.39|moisturizer/humectant|
# <br>
#
# 5. 주효능별 성분 수 (내림차순) + 효능 별 TOP3 성분 (포함 제품 수 기준)
#    |순위|주효능|성분 수|#1(해당 성분 포함 제품 수)|#2(해당 성분 포함 제품 수)|#3(해당 성분 포함 제품 수)|
#    |---|---|---|---|---|---|
#    |1|emollient|899|dimethicone  (16,775)|caprylic-capric-triglyceride  (16,504)|cetearyl-alcohol  (15,590)|
#    |2|antioxidant|632|tocopherol (22,333)|tocopheryl-acetate  (18,802)|camellia-sinensis-leaf-extract   (8,520)|
#    |3|perfuming|570|<span style="color:red">parfum (36,094)</span>|linalool   (13,672)'|limonene   (12,711)|
#    |4|surfactant/cleansing|535|peg-100-stearate (5,652)|cocamidopropyl-betaine  (5,551)|decyl-glucoside (3,374)|
#    |5|moisturizer/humectant|514|<span style="color:red">butylene-glycol (24,942)</span>|caprylyl-glycol (16,992)|propylene-glycol (12,806)|
#    |6|emulsifying|503|polysorbate-20(7421)|peg-40-hydrogenated-castor-oil(4117)|polysorbate-60(3989)|
#    |7|viscosity controlling|407|xanthan-gum  (22,376)|carbomer (13,247)|sodium-chloride  (9,317)|
#    |8|antimicrobial/antibacterial|230|alcohol   (6,560)|alcohol-denat (4,261)|lavandula-angustifolia-oil (3,240)|
#    |9|abrasive/scrub|170|talc (1,894)|charcoal-powder   (855)|oryza-sativa-extract (723)|
#    |10|soothing|152|panthenol (15,715)|allantoin  (11,072)|aloe-barbadensis-leaf-juice   (9,034)|
#    |11|solvent|130|<span style="color:red">water   (67,796)</span>|1-2-hexanediol (13,093)|propanediol   (12,112)|
#    |12|buffering|109|citric-acid (22,393)|sodium-hydroxide  (13,457)|triethanolamine   (5,775)|
#    |13|colorant|104|ci-77891  (6,775)|mica  (5,186)|iron-oxides (3,960)|
#    |14|preservative|85|<span style="color:red">phenoxyethanol   (36,755)</span>|ethylhexylglycerin (23,514)|sodium-benzoate (14,899)|
#    |15|cell-communicating ingredient|74|niacinamide   (11,285)|adenosine   (4,362)|retinyl-palmitate  (2,997)']
#    |16|skin brightening|52|magnesium-ascorbyl-phosphate   (1,043)|tranexamic-acid (457)|citrus-unshiu-peel-extract  (388)|
#    |17|chelating|43|disodium-edta (22,870)|sodium-citrate   (5,177)|tetrasodium-edta (3,712)|
#    |18|skin-identical ingredient|38|<span style="color:red">glycerin (55,954)</span>|sodium-hyaluronate   (19,878)|squalane  (7,051)|
#    |19|sunscreen|31|titanium-dioxide (5,914)|ethylhexyl-methoxycinnamate (4,186)|butyl-methoxydibenzoylmethane  (3,708)|
#    |20|exfoliant|14|lactic-acid   (6,379)|salicylic-acid   (5,075)|glycolic-acid (2,681)|
#    |21|anti-acne|6|lauric-acid (1,187)|zinc-gluconate (1,017)|zinc-pca (951)|
#
#    &rarr; 활용도 TOP 5 성분들을 강조하여, 다수의 상품에 공통으로 사용된 성분들의 특성(효능) 확인
#    &rarr; 성분의 특성(효능)에 따른 특이점은 확인되지 않음

# %% [markdown]
# 6. 제품군별 TOP10 성분 (포함 제품 수 기준)
#
#     |serum|	essence|	mist	|emulsion|	cream|	lotion|	toner|
#     |--|--|--|--|--|--|--|
#     |	<span style="color:red">water|	<span style="color:red">water|<span style="color:red">	water	|<span style="color:red">water|	<span style="color:red">water	|<span style="color:red">water|	<span style="color:red">water|
#     |	<span style="color:red">glycerin	|<span style="color:red">glycerin	|<span style="color:red">glycerin|	<span style="color:red">glycerin|	<span style="color:red">glycerin|	<span style="color:red">glycerin|	<span style="color:red">glycerin|
#     |	<span style="color:red">phenoxyethanol	|<span style="color:red">butylene-glycol|	<span style="color:red">phenoxyethanol|	<span style="color:red">butylene-glycol|	<span style="color:red">phenoxyethanol|	<span style="color:red">phenoxyethanol	|<span style="color:red">butylene-glycol|
#     |	sodium-hyaluronate	|<span style="color:red">phenoxyethanol	|<span style="color:red">butylene-glycol|	disodium-edta|	cetearyl-alcohol|	<span style="color:red">parfum|	1-2-hexanediol|
#     |	xanthan-gum	|sodium-hyaluronate|	<span style="color:red">parfum	|dimethicone|	glyceryl-stearate	|cetearyl-alcohol	|ethylhexylglycerin|
#     |	<span style="color:red">butylene-glycol	|disodium-edta|	ethylhexylglycerin|	carbomer|	dimethicone|	xanthan-gum	|<span style="color:red">phenoxyethanol|
#     |	ethylhexylglycerin|	ethylhexylglycerin	|citric-acid|	<span style="color:red">parfum|	<span style="color:red">butylene-glycol|	dimethicone|	sodium-hyaluronate|
#     |	niacinamide	|1-2-hexanediol	|sodium-hyaluronate	|glyceryl-stearate|	<span style="color:red">parfum|	glyceryl-stearate	|disodium-edta|
#     |tocopherol	|<span style="color:red">parfum	|disodium-edta|	ethylhexylglycerin|	caprylic-capric-triglyceride|	disodium-edta|	panthenol|
#     |	disodium-edta|	xanthan-gum|	propanediol	|<span style="color:red">phenoxyethanol	|xanthan-gum	|tocopheryl-acetate|	allantoin|

# %% [markdown]
# 7. essense 제품 5개 표본
# <br>
# <br>
# 단순히 위의 표(많이 쓰인 성분)를 정확도 지표로 쓰기에는 조금 어려울수도 있음
# <br>
# 제품 별로 성분의 순서가 다 다름, water나 glycerin 등 가장 많이 쓰이는 두 성분은 유효
# <br>
# <br>
#
#     < 001-skincare-rosa-damascena-essence-mist >
#     <br>
#     ["['rosa-damascena-flower-water'", " 'polysorbate-20'", " 'benzyl-alcohol'", " 'dehydroacetic-acid'", " 'rosa-damascena-flower-oil'", " 'water'", " 'tocopherol'", " 'citronellol'", " 'geraniol'", " 'methyl-eugenol']"]
#     <br>
#     <br>
#     < 1004-laboratory-atvt-bifida-77-hexa-layer-fermentation-essence >
#     <br>
#     ["['bifida-ferment-lysate'", " 'hydrogenated-polyisobutene'", " 'glycerin'", " 'coco-caprylate-caprate'", " 'niacinamide'", " 'polyglyceryl-2-stearate'", " 'glyceryl-stearate'", " 'sodium-hyaluronate'", " 'nelumbo-nucifera-flower-water'", " 'silica'"]
#     <br>
#     <br>
#     < 111skin-antioxidant-energising-essence >
#     <br>
#     ["['water'", " 'glycerin'", " 'sorbitol'", " 'polysorbate-20'", " 'benzyl-alcohol'", " 'macrocystis-pyrifera-extract'", " 'tartaric-acid'", " 'aloe-barbadensis-leaf-extract'", " 'tetrahexyldecyl-ascorbate'", " 'xanthan-gum'"]
#     <br>
#     <br>
#     < 23-5degn-rice-soothing-active-essence >
#     <br>
#     ["['rice-ferment-filtrate'", " 'oryza-sativa-extract'", " 'sodium-hyaluronate'", " 'carbomer'", " 'glycerin'", " 'phenoxyethanol'", " 'chlorphenesin']"]
#     <br>
#     <br>
#     < 2ndesign-first-toner-essence >
#     <br>
#     ["['water'", " 'butylene-glycol'", " 'glycerin'", " '1-2-hexanediol'", " 'betaine'", " 'glycereth-25-pca-isostearate'", " 'arginine'", " 'acrylates-c10-30-alkyl-acrylate-crosspolymer'", " 'panthenol'", " 'caprylic-capric-triglyceride'"]

# %% [markdown]
# 8. 자외선 차단 제품군별 TOP10 성분(<span style="color:yellow">노란 부분은 'sunscreen' effect를 가지고 있는 성분들)
# <br>
#
#     |sunblock	|sunscreen	|sun-cream	|sun-stick|
#     |--|--|--|--|
#     |water	|water	|water	|<span style="color:yellow">bis-ethylhexyloxyphenol-methoxyphenyl-triazine
#     |<span style="color:yellow">ethylhexyl-methoxycinnamate	|glycerin	|glycerin	|water|
#     |glycerin	|<span style="color:yellow">zinc-oxide|	butylene-glycol	|<span style="color:yellow">diethylamino-hydroxybenzoyl-hexyl-benzoate|
#     |<span style="color:yellow">zinc-oxide	|phenoxyethanol	|<span style="color:yellow">titanium-dioxide	|<span style="color:yellow">ethylhexyl-salicylate|
#     |butylene-glycol	|<span style="color:yellow">titanium-dioxide|	1-2-hexanediol	|<span style="color:yellow">ethylhexyl-methoxycinnamate|
#     |<span style="color:yellow">titanium-dioxide|	dimethicone	|ethylhexylglycerin|	butylene-glycol|
#     |dimethicone	|<span style="color:yellow">butyl-methoxydibenzoylmethane|	stearic-acid	|vinyl-dimethicone-methicone-silsesquioxane-cro...|
#     |disodium-edta|	tocopheryl-acetate|	<span style="color:yellow">ethylhexyl-salicylate	|polyethylene|
#     |cyclopentasiloxane	|<span style="color:yellow">ethylhexyl-methoxycinnamate	|tocopherol	|1-2-hexanediol|
#     |glyceryl-stearate|<span style="color:yellow">	octocrylene|	xanthan-gum	|silica|

# %% [markdown]
# 9. 세정/세안제 제품군별 TOP10 성분(<span style="color:lightgreen">연두색 부분은 'surfactant/cleansing' effect를 가지고 있는 성분들)
# <br>
#
#     |cleanser	|cleansing-foam|	cleansing-balm	|cleansing-oil
#     |--|--|--|--|
#     |water	|water	|caprylic-capric-triglyceride	|caprylic-capric-triglyceride|
#     |	glycerin|	glycerin	|water	|water|
#     |phenoxyethanol	|butylene-glycol	|tocopherol|	helianthus-annuus-seed-oil|
#     |	citric-acid	|disodium-edta	|glycerin	|tocopherol|
#     |	<span style="color:lightgreen">cocamidopropyl-betaine|	<span style="color:lightgreen">myristic-acid	|helianthus-annuus-seed-oil|	simmondsia-chinensis-seed-oil|
#     |	parfum	|stearic-acid	|butyrospermum-parkii-butter	|olea-europaea-fruit-oil|
#     |	disodium-edta	|potassium-hydroxide|	ethylhexyl-palmitate	|parfum|
#     |	sodium-chloride	|<span style="color:lightgreen">lauric-acid	|phenoxyethanol	|glycerin|
#     |	butylene-glycol	|<span style="color:lightgreen">cocamidopropyl-betaine|	parfum|	<span style="color:lightgreen">peg-20-glyceryl-triisostearate|
#     |	ethylhexylglycerin	|sodium-chloride	|<span style="color:lightgreen">peg-20-glyceryl-triisostearate	|tocopheryl-acetate|

# %% [markdown]
# ### '성분-효능(목록)' 데이터

# %%
inci_ing = pd.read_csv('inci_ing_final.csv')
inci_ing.head()
# Out:
#                                          ingredients  \
# 0                       Aloe Barbadensis Leaf Juice
# 1                      Arabidopsis Thaliana Extract
# 2  Artemisia Princeps Leaf Extract (Soothing/Ant...
# 3                        Cananga Odorata Flower Oil
# 4                      Caprylic/Capric Triglyceride
#
#              formatted ingredients                           what-it-does
# 0      aloe-barbadensis-leaf-juice  ['soothing', 'moisturizer/humectant']
# 1     arabidopsis-thaliana-extract                        ['antioxidant']
# 2  artemisia-princeps-leaf-extract                                   ['']
# 3       cananga-odorata-flower-oil                          ['perfuming']
# 4     caprylic-capric-triglyceride                          ['emollient']

# %%
# 데이터 1차 확인 : 성분데이터 72,690개
inci_ing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72691 entries, 0 to 72690
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ingredients            72690 non-null  object
#  1   formatted ingredients  72691 non-null  object
#  2   what-it-does           72691 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# #### 중복데이터 확인 및 처리

# %%
# 'formatted ingredients' 상 동일 성분이나, 'ingredients' 표기방식에 따른 중복데이터 확인됨
inci_ing[inci_ing['formatted ingredients']=='water']
# Out:
#               ingredients formatted ingredients what-it-does
# 27                  "Aqua                 water  ['solvent']
# 28          "Aqua (Water)                 water  ['solvent']
# 29     "Aqua (Water, Eau)                 water  ['solvent']
# 30          "Aqua [Water]                 water  ['solvent']
# 75          "Water (Aqua)                 water  ['solvent']
# ...                   ...                   ...          ...
# 72605              ‬‭Aqua                 water  ['solvent']
# 72614               ‭Aqua                 water  ['solvent']
# 72656              ‭Water                 water  ['solvent']
# 72684              ﻿Water                 water  ['solvent']
# 72685        ﻿Water(Aqua)                 water  ['solvent']
#
# [696 rows x 3 columns]

# %%
# 'ing_effect_dict' 딕셔너리에 각 성분별 효능을 리스트 타입으로 변환 
ing_effect_dict = defaultdict()
for i,effects in enumerate(inci_ing['what-it-does']): 

    # 텍스트 형식으로 나열된 효능들을 리스트 형식으로 변환
    each = effects.split("'")
    tmp = []
    for e in each:
        if len(e) != 1:
            if ',' not in e:
                tmp.append(e)

    # 성분 ('formatted ingredients' 기재 방식) 기준으로 효능 리스트를 담음 (중복데이터 제거됨)
    ing_effect_dict[inci_ing['formatted ingredients'][i]] = tmp

print('Unique Ingridients Count: ',len(ing_effect_dict.keys()))

# 'ing_effect_dict'를 데이터프레임으로 변환
ing_effects = pd.DataFrame({'ingredient':ing_effect_dict.keys(),'effects':ing_effect_dict.values()})
ing_effects
# Out:
# Unique Ingridients Count:  15186
#                                           ingredient  \
# 0                        aloe-barbadensis-leaf-juice
# 1                       arabidopsis-thaliana-extract
# 2                    artemisia-princeps-leaf-extract
# 3                         cananga-odorata-flower-oil
# 4                       caprylic-capric-triglyceride
# ...                                              ...
# 15181  sr-wasp-spider-polypeptide-1-oligopeptide-178
# 15182                              a-olefin-oligomer
# 15183                                      b-dextran
# 15184                           frankincense-gum-oil
# 15185                 kojilmecilrendiogsisinnameiteu
#
#                                  effects
# 0      [soothing, moisturizer/humectant]
# 1                          [antioxidant]
# 2                                     []
# 3                            [perfuming]
# 4                            [emollient]
# ...

# %%
ing_effects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15186 entries, 0 to 15185
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ingredient  15186 non-null  object
#  1   effects     15186 non-null  object
# dtypes: object(2)
# memory usage: 237.4+ KB

# %% [markdown]
# ### '성분-계-효능' 데이터

# %% [markdown]
# #### '성분별 활용 횟수/비율' 데이터 (활용 수 기준 내림차순 정렬)에 '성분-효능' 데이터 병합

# %%
# '성분-효능'
ing_count_effect = pd.merge(ing_count,ing_effects,how="outer", on="ingredient")
ing_count_effect
# Out:
#                                               ingredient  count  used %  \
# 0                                                  water  67796   88.05
# 1                                               glycerin  55954   72.67
# 2                                         phenoxyethanol  36755   47.73
# 3                                                 parfum  36094   46.88
# 4                                        butylene-glycol  24942   32.39
# ...                                                  ...    ...     ...
# 15181  lactobacillus-pueraria-mirifica-root-ferment-f...      1    0.00
# 15182  aspergillus-saccharomyces-pumpkin-seed-ferment...      1    0.00
# 15183  saccharomyces-prunus-mume-extract-ferment-filt...      1    0.00
# 15184  saccharomyces-day-lily-flower-honey-ferment-fi...      1    0.00
# 15185  aspergillus-saccharomyces-glycyrrhiza-uralensi...      1    0.00
#
#                                                  effects
# ...

# %% [markdown]
# #### 성분별 효능목록 0번째 나열된 효능을 '주효능'으로 구분

# %%
# 성분별 0번째 효능을 '주효능'으로 구분하여 
main_effect_dict = {}
for i,e in tqdm_notebook(enumerate(ing_count_effect['effects'])):
    if e[0] != '':
        main_effect_dict[ing_count_effect['ingredient'][i]] = e[0]
    else:
        # 성분에 대하여 표기된 효능이 없는 경우 NaN처리
        main_effect_dict[ing_count_effect['ingredient'][i]] = np.NaN 

main_effect = pd.DataFrame({'ingredient':main_effect_dict.keys(),'main effect':main_effect_dict.values()})
main_effect
# Out:
# C:\Users\jihyu\AppData\Local\Temp\ipykernel_10248\1361452452.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i,e in tqdm_notebook(enumerate(ing_count_effect['effects'])):
# 0it [00:00, ?it/s]
#                                               ingredient  \
# 0                                                  water
# 1                                               glycerin
# 2                                         phenoxyethanol
# 3                                                 parfum
# 4                                        butylene-glycol
# ...                                                  ...
# 15181  lactobacillus-pueraria-mirifica-root-ferment-f...
# 15182  aspergillus-saccharomyces-pumpkin-seed-ferment...
# 15183  saccharomyces-prunus-mume-extract-ferment-filt...
# 15184  saccharomyces-day-lily-flower-honey-ferment-fi...
# ...

# %% [markdown]
# #### '성분-계-효능(목록)' 데이터와 '성분-주효능' 데이터 병합

# %%
ing_count_effect = pd.merge(ing_count_effect,main_effect,how="outer", on="ingredient")
ing_count_effect
# Out:
#                                               ingredient  count  used %  \
# 0                                                  water  67796   88.05
# 1                                               glycerin  55954   72.67
# 2                                         phenoxyethanol  36755   47.73
# 3                                                 parfum  36094   46.88
# 4                                        butylene-glycol  24942   32.39
# ...                                                  ...    ...     ...
# 15181  lactobacillus-pueraria-mirifica-root-ferment-f...      1    0.00
# 15182  aspergillus-saccharomyces-pumpkin-seed-ferment...      1    0.00
# 15183  saccharomyces-prunus-mume-extract-ferment-filt...      1    0.00
# 15184  saccharomyces-day-lily-flower-honey-ferment-fi...      1    0.00
# 15185  aspergillus-saccharomyces-glycyrrhiza-uralensi...      1    0.00
#
#                                                  effects  \
# ...

# %% [markdown]
# #### '효능-성분' 데이터 (전체 효능/중복 허용)

# %%
# 각 효능(용도) 별 성분표 추출 

from collections import defaultdict
effect_dict = defaultdict(list)
for i,effects in tqdm_notebook(enumerate(ing_count_effect['effects'])):
    for effect in effects:
        if effect in effect_dict:
            effect_dict[effect].append(ing_count_effect['ingredient'][i])
        else:
            effect_dict[effect] = [ing_count_effect['ingredient'][i]]
# Out:
# C:\Users\jihyu\AppData\Local\Temp\ipykernel_10248\2053825156.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i,effects in tqdm_notebook(enumerate(ing_count_effect['effects'])):
# 0it [00:00, ?it/s]

# %%
# '효능-성분' 생성 (컬럼: 효능)
effect_ing = pd.DataFrame.from_dict(effect_dict,orient='index').T

# 효능이 기재되어 있지 않은 성분들의 컬럼을 'Unknown'으로 지정하고 별도 저장 후, '효능-성분'표에서는 삭제
effect_ing.rename(columns={'': 'Unknown'},inplace=True)
effect_unknown_ing = effect_ing['Unknown']
del effect_ing['Unknown']
effect_ing.dropna(how='all',inplace=True)

effect_ing
# Out:
#                solvent skin-identical ingredient moisturizer/humectant  \
# 0                water                  glycerin              glycerin
# 1      butylene-glycol        sodium-hyaluronate       butylene-glycol
# 2       1-2-hexanediol                  squalane    sodium-hyaluronate
# 3     propylene-glycol                  arginine       caprylyl-glycol
# 4             limonene                sodium-pca             panthenol
# ...                ...                       ...                   ...
# 1020              None                      None                  None
# 1021              None                      None                  None
# 1022              None                      None                  None
# 1023              None                      None                  None
# 1024              None                      None                  None
#
#             preservative       perfuming         chelating         buffering  \
# ...

# %%
effect_unknown_ing
# Out:
# 0                                            maltodextrin
# 1                                 triethoxycaprylylsilane
# 2                                polymethylsilsesquioxane
# 3                                       sodium-levulinate
# 4                             rosa-damascena-flower-water
#                               ...
# 9883                                      croton-lechleri
# 9884    lactobacillus-pueraria-mirifica-root-ferment-f...
# 9885    aspergillus-saccharomyces-pumpkin-seed-ferment...
# 9886    saccharomyces-day-lily-flower-honey-ferment-fi...
# 9887    aspergillus-saccharomyces-glycyrrhiza-uralensi...
# Name: Unknown, Length: 9888, dtype: object

# %%
effect_ing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 0 to 1024
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   solvent                        239 non-null    object
#  1   skin-identical ingredient      39 non-null     object
#  2   moisturizer/humectant          720 non-null    object
#  3   preservative                   120 non-null    object
#  4   perfuming                      661 non-null    object
#  5   chelating                      68 non-null     object
#  6   buffering                      121 non-null    object
#  7   viscosity controlling          691 non-null    object
#  8   antioxidant                    712 non-null    object
#  9   emollient                      1025 non-null   object
#  10  soothing                       218 non-null    object
#  11  emulsifying                    775 non-null    object
# ...

# %%
effect_ing.to_csv('final_effect_ing.csv',index=False)

# %% [markdown]
# ### 최종 데이터 확인

# %%
ing_count_effect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15186 entries, 0 to 15185
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ingredient   15186 non-null  object
#  1   count        15186 non-null  int64
#  2   used %       15186 non-null  float64
#  3   effects      15186 non-null  object
#  4   main effect  5298 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.2+ MB

# %%
print(f'총 15,186개 성분 중 효능 표기 성분 5,298개(전체 데이터 {round(5298/15816*100)}%)')
print(f'효능 표기 누락 성분 {15816-5298}개')
# Out:
# 총 15,186개 성분 중 효능 표기 성분 5,298개(전체 데이터 33%)
# 효능 표기 누락 성분 10518개

# %%
print('효능별 성분 수')
ing_count_effect['main effect'].value_counts()
# Out:
# 효능별 성분 수
# emollient                        899
# antioxidant                      632
# perfuming                        570
# surfactant/cleansing             535
# moisturizer/humectant            514
# emulsifying                      503
# viscosity controlling            407
# antimicrobial/antibacterial      230
# abrasive/scrub                   170
# soothing                         152
# solvent                          130
# buffering                        109
# colorant                         104
# preservative                      85
# cell-communicating ingredient     74
# skin brightening                  52
# chelating                         43
# skin-identical ingredient         38
# sunscreen                         31
# exfoliant                         14
# anti-acne                          6
# Name: main effect, dtype: int64

# %%
effect_top5ing_dict = {}
for e in [l for l in ing_count_effect['main effect'].unique() if str(l) != 'nan']:
    sub = ing_count_effect[ing_count_effect['main effect']==e][:3].reset_index()
    tmp = []
    for i in range(3):
        tmp.append(f"{sub['ingredient'][i]}({sub['count'][i]})")
    effect_top5ing_dict[e] = tmp
effect_top5ing = pd.DataFrame({'main effect':effect_top5ing_dict.keys(),'Top 5 ingredients(count)':effect_top5ing_dict.values()})
main_effect_top5ing = pd.DataFrame({'main effect':ing_count_effect['main effect'].value_counts().keys(),'count':ing_count_effect['main effect'].value_counts()})

# %%
main_effect_top5ing = pd.merge(main_effect_top5ing,effect_top5ing,how='outer',on='main effect')
main_effect_top5ing
# Out:
#                       main effect  count  \
# 0                       emollient    899
# 1                     antioxidant    632
# 2                       perfuming    570
# 3            surfactant/cleansing    535
# 4           moisturizer/humectant    514
# 5                     emulsifying    503
# 6           viscosity controlling    407
# 7     antimicrobial/antibacterial    230
# 8                  abrasive/scrub    170
# 9                        soothing    152
# 10                        solvent    130
# 11                      buffering    109
# 12                       colorant    104
# 13                   preservative     85
# 14  cell-communicating ingredient     74
# 15               skin brightening     52
# 16                      chelating     43
# 17      skin-identical ingredient     38
# 18                      sunscreen     31
# 19                      exfoliant     14
# 20                      anti-acne      6
#
# ...

# %%
print('TOP 10 ingredients, used count,used %, effects list & main effect: ')
ing_count_effect[:10]
# Out:
# TOP 10 ingredients, used count,used %, effects list & main effect:
#            ingredient  count  used %  \
# 0               water  67796   88.05
# 1            glycerin  55954   72.67
# 2      phenoxyethanol  36755   47.73
# 3              parfum  36094   46.88
# 4     butylene-glycol  24942   32.39
# 5  ethylhexylglycerin  23514   30.54
# 6       disodium-edta  22870   29.70
# 7         citric-acid  22393   29.08
# 8         xanthan-gum  22376   29.06
# 9          tocopherol  22333   29.00
#
#                                              effects  \
# 0                                          [solvent]
# 1  [skin-identical ingredient, moisturizer/humect...
# 2                                     [preservative]
# 3                                        [perfuming]
# 4                   [moisturizer/humectant, solvent]
# 5                                     [preservative]
# 6                                        [chelating]
# ...

# %% [markdown]
# ### 데이터 시각화

# %%
plt.rcParams['figure.figsize'] = [20, 12]
fig = plt.figure(1)
box = sns.boxplot(y='count',x='main effect',palette='GnBu',data = ing_count_effect)
labels = [l for l in ing_count_effect['main effect'].unique() if str(l) != 'nan']
box.set_xticklabels(labels,rotation=90)
plt.show()

# %%
# Set cut_point (Top 97%)
cut_point = ing_count_effect['count'].quantile(0.99)
ing_count_effect_cut= ing_count_effect[ing_count_effect['count'] < cut_point]
print('Number of Ingredients Eliminated : ', len(ing_count_effect['ingredient']) - len(ing_count_effect_cut['ingredient']))
ing_count_cut.describe()
# Out:
# Number of Ingredients Eliminated :  152
#               count        used %
# count  15034.000000  15034.000000
# mean      59.564653      0.076777
# std      204.624029      0.265961
# min        1.000000      0.000000
# 25%        1.000000      0.000000
# 50%        4.000000      0.010000
# 75%       22.000000      0.030000
# max     2377.000000      3.090000

# %%
plt.rcParams['figure.figsize'] = [20, 12]
fig = plt.figure(1)
sns.histplot(data = ing_count_effect_cut,x='count',hue='main effect',kde=True,multiple='stack')
plt.show()

# %%
plt.figure(figsize=(10,5))
ing_count_effect_cut['count'].hist()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 12]
fig = plt.figure(1)
box = sns.boxplot(y='count',x='main effect',palette='GnBu',data = ing_count_effect_cut)
labels = [l for l in ing_count_effect_cut['main effect'].unique() if str(l) != 'nan']
box.set_xticklabels(labels,rotation=90)
plt.show()

# %% [markdown]
# #### Save File: 'skca_ing_count_effect.csv'

# %%
ing_count_effect.to_csv('skca_ing_count_effect.csv',index=False)

# %% [markdown]
# ## 제품별 포함된 성분 WORDCLOUD

# %%
prod_ing_effect = pd.read_csv('final_prod_ing_effect.csv',index_col=False)
prod_ing_effect
# Out:
#                                            product                 ingredient  \
# 0        001-skincare-active-marine-collagen-serum                      water
# 1        001-skincare-active-marine-collagen-serum  rubus-idaeus-leaf-extract
# 2        001-skincare-active-marine-collagen-serum             polysorbate-20
# 3        001-skincare-active-marine-collagen-serum                   limonene
# 4        001-skincare-active-marine-collagen-serum          potassium-sorbate
# ...                                            ...                        ...
# 2041841         zyu-complexion-perfector-spf-50-pa                niacinamide
# 2041842         zyu-complexion-perfector-spf-50-pa         tocopheryl-acetate
# 2041843         zyu-complexion-perfector-spf-50-pa                      water
# 2041844         zyu-complexion-perfector-spf-50-pa            butylene-glycol
# 2041845                                        NaN                     effect
#
# ...

# %%
# 성분 워드클라우드
wordcloud = WordCloud(width=1200, height=800).generate(' '.join(prod_ing_effect['ingredient']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
