# %% [markdown]
# # Imports

# %%
import pandas as pd
from tqdm import notebook
from collections import defaultdict
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %% [markdown]
# # Data

# %%
inci_prod = pd.read_csv('./data/inci_prod_final.csv')
inci_prod
# Out:
#                                             product name  \
# 0              001-skincare-active-marine-collagen-serum
# 1      001-skincare-alpha-glow-flash-facial-serum-pri...
# 2              001-skincare-alpha-paradise-cleansing-dew
# 3         001-skincare-amino-acids-lipids-recovery-cream
# 4         001-skincare-beighten-plump-emulsion-clay-mask
# ...                                                  ...
# 76995            zymogen-fermented-soybean-firming-serum
# 76996            zymogen-houttuynia-cordata-ferment-mist
# 76997           zymogen-houttuynia-cordata-ferment-serum
# 76998               zymogen-long-lasting-power-sun-cream
# 76999                 zyu-complexion-perfector-spf-50-pa
#
#                                              ingredients  \
# 0      ['Aqua', 'Aloe Barbadensis Leaf Extract', 'Pol...
# 1      ['Aqua', 'Rosa Damascena Flower Water', 'Aloe ...
# 2      ['Prunus Amygdalus Dulcis Oil (Sweet Almond)',...
# 3      ['Aqua', 'Helianthus Annuus Seed Oil*', 'Butyr...
# 4      ['Aqua', 'Kaolin', 'Glycerin', 'Bentonite', 'P...
# ...                                                  ...
# 76995  ['Water', 'Butylene Glycol', 'Peg/Ppg-18/4 Cop...
# 76996  ['Water', 'Butylene Glycol', 'Bacillus/Glutami...
# 76997  ['Water', 'Alcohol', 'Butylene Glycol', 'Sodiu...
# 76998  ['Water', 'Ethylhexyl Methoxycinnamate', 'Glyc...
# 76999  ['Water', 'Titanium Dioxide', 'Ethylhexyl Meth...
#
#                                    formatted ingredients
# 0      ['water', 'aloe-barbadensis-leaf-extract', 'po...
# 1      ['water', 'rosa-damascena-flower-water', 'aloe...
# 2      ['prunus-amygdalus-dulcis-oil', 'simmondsia-ch...
# 3      ['water', 'helianthus-annuus-seed-oil', 'butyr...
# 4      ['water', 'kaolin', 'glycerin', 'bentonite', '...
# ...                                                  ...
# 76995  ['water', 'butylene-glycol', 'peg-ppg-18-4-cop...
# 76996  ['water', 'butylene-glycol', 'bacillus-glutami...
# 76997  ['water', 'alcohol', 'butylene-glycol', 'sodiu...
# 76998  ['water', 'ethylhexyl-methoxycinnamate', 'glyc...
# 76999  ['water', 'titanium-dioxide', 'ethylhexyl-meth...
#
# [77000 rows x 3 columns]

# %%
ing_effect = pd.read_csv('./data/skca_ing_count_effect.csv')
ing_lst = ing_effect['ingredient'].unique()

# %% [markdown]
# # master_df

# %%
column_names = ['product']
column_names.extend(ing_lst)
master_df = pd.DataFrame(columns = column_names)
master_df
# Out:
# Empty DataFrame
# Columns: [product, water, glycerin, phenoxyethanol, parfum, butylene-glycol, ethylhexylglycerin, disodium-edta, citric-acid, xanthan-gum, tocopherol, sodium-hyaluronate, tocopheryl-acetate, caprylyl-glycol, dimethicone, caprylic-capric-triglyceride, panthenol, cetearyl-alcohol, sodium-benzoate, linalool, glyceryl-stearate, potassium-sorbate, sodium-hydroxide, carbomer, 1-2-hexanediol, propylene-glycol, limonene, propanediol, butyrospermum-parkii-butter, niacinamide, allantoin, helianthus-annuus-seed-oil, sodium-chloride, cetyl-alcohol, stearic-acid, aloe-barbadensis-leaf-juice, benzyl-alcohol, pentylene-glycol, camellia-sinensis-leaf-extract, silica, cyclopentasiloxane, polysorbate-20, simmondsia-chinensis-seed-oil, acrylates-c10-30-alkyl-acrylate-crosspolymer, squalane, citronellol, geraniol, ci-77891, alcohol, lecithin, lactic-acid, titanium-dioxide, betaine, triethanolamine, methylparaben, bht, dipropylene-glycol, peg-100-stearate, cocamidopropyl-betaine, chlorphenesin, mica, sodium-citrate, arginine, salicylic-acid, aloe-barbadensis-leaf-extract, centella-asiatica-extract, olea-europaea-fruit-oil, chamomilla-recutita-flower-extract, hexyl-cinnamal, hydroxyethylcellulose, hydrogenated-lecithin, adenosine, prunus-amygdalus-dulcis-oil, sodium-pca, alcohol-denat, ethylhexyl-methoxycinnamate, ceramide-np, cocos-nucifera-oil, peg-40-hydrogenated-castor-oil, c12-15-alkyl-benzoate, polysorbate-60, glycyrrhiza-glabra-root-extract, iron-oxides, benzyl-salicylate, glyceryl-caprylate, citral, argania-spinosa-kernel-oil, ascorbic-acid, rosmarinus-officinalis-leaf-extract, tetrasodium-edta, butyl-methoxydibenzoylmethane, cera-alba, dehydroacetic-acid, ci-19140, bisabolol, tromethamine, hyaluronic-acid, ci-77491, stearyl-alcohol, ascorbyl-palmitate, ...]
# Index: []
#
# [0 rows x 15187 columns]

# %% [markdown]
# # Modules

# %%
def get_cnt_vec(product):
    vector = [product]
    tmp_lst = inci_prod[inci_prod['product name']==product]['formatted ingredients'].values[0]
    prod_ings = []
    for txt in tmp_lst.split("'"):
        if "," not in txt and "[" not in txt and "]" not in txt:
            prod_ings.append(txt)
    
    for ing in ing_lst:
        i = 1 if ing in prod_ings else 0
        vector.append(i)
    return vector[1:]

# %%
def get_sqc_inv_vec(product):
    vector = [product]
    prod_ings = get_inglst(product)

    for ing in ing_lst:
        i = 1/(1+prod_ings.index(ing)) if ing in prod_ings else 0
        vector.append(i)
    return vector[1:]

# %%
def get_inglst(prod):
    df = inci_prod[inci_prod['product name']==prod]
    inglst = []
    tmp = list(df['formatted ingredients'])
    for txt in tmp[0].split("'"):
        if "," not in txt and "[" not in txt and "]" not in txt:
            inglst.append(txt)
    return inglst

# %%
def compare_prods(pname1,pname2):
    '''returns union,interx,unique1,unique2'''
    prd1,prd2 = get_inglst(pname1),get_inglst(pname2)
    
    union = list(set(prd1) | set(prd2))
    interx = list(set(prd1) & set(prd2))
    uq1 = list(set(prd1) - set(prd2))
    uq2 = list(set(prd2) - set(prd1))
    return union, interx, uq1, uq2

# %%
def ing_df(inglst):
    df = pd.DataFrame(columns=['ingredient','count','used %','effects','main effect'])
    for ing in inglst:
        tmp_df = ing_effect[ing_effect['ingredient']==ing]
        df = pd.concat([df,tmp_df],ignore_index=True)
    return df

# %%
def cos_sim(x,y):
    return round(dot(x, y)/(norm(x)*norm(y)),3)

def euc_dist(x,y):   
    return round(np.sqrt(np.sum((x-y)**2)),3)

# %%
def create_link_inci_decoder(prod1,prod2):
    p1 = inci_prod[inci_prod['product name'].str.contains(prod1)]['product name'].values[0]
    p2 = inci_prod[inci_prod['product name'].str.contains(prod2)]['product name'].values[0]
    return f'https://incidecoder.com/compare-products/{p1}/{p2}'

# %%
def comparison_summary(prod1,prod2):
    testA = inci_prod[inci_prod['product name'].str.contains(prod1)]['product name'].values[0]
    testB = inci_prod[inci_prod['product name'].str.contains(prod2)]['product name'].values[0]
    cos_sim_cnt = cos_sim(get_cnt_vec(testA),get_cnt_vec(testB))
    cos_sim_sqc = cos_sim(get_sqc_inv_vec(testA),get_sqc_inv_vec(testB))
    # euc_dist_cnt = euc_dist(get_cnt_vec(testA),get_cnt_vec(testB))
    # euc_dist_sqc = euc_dist(get_sqc_inv_vec(testA),get_sqc_inv_vec(testB))
    union,interx,unique1,unique2 = compare_prods(testA,testB)
    print('='*130)
    print('[ Products Ingredients Comparison Summary ]')
    print()
    print('Product A:',testA)
    print('Product B:',testB)
    print(create_link_inci_decoder(testA,testB))
    print()
    print('-'*130)
    print('[ Similarity Measurement ]')
    print('Cosine Similarity - Count-based: ',cos_sim_cnt)
    print('Cosine Similarity - Sequence-based(inverse): ',cos_sim_sqc)
    # print()
    # print('Euclidean Distance - Count-based: ',euc_dist_cnt)
    # print('Euclidean Distance - Sequence-based(inverse): ',euc_dist_sqc)
    print('-'*130)
    print('[ Ingredients Comparison ]')
    print('Total # of Ingredients:',len(union))
    print('Total # of Common Ingredients:',len(interx))
    print('Product A # of Unique:', len(unique1))
    print('Product B # of Unique:', len(unique2))
    print('-'*130)
    print('[ Common Ingredients ]')
    display(ing_df(interx))
    print()
    print('-'*130)
    print(f'[ Unique Ingredients of {testA} ]')
    display(ing_df(unique1))
    print()
    print('-'*130)
    print(f'[ Unique Ingredients of {testB} ]')
    display(ing_df(unique2))
    print('='*130)

# %% [markdown]
# # Product Comparison Summary

# %%
#comparison_summary('joah-skin-polish-gold-peel-off-mask','7th-heaven-tea-tree-peel-off')
comparison_summary('foreo-serum-serum-serum','aprilskin-20-vitamin-a-c-e-brightening-serum')
#comparison_summary('foreo-serum-serum-serum','awake-beauty-glow-pill-super-serum')
# Out:
# ==================================================================================================================================
# [ Products Ingredients Comparison Summary ]
#
# Product A: foreo-serum-serum-serum
# Product B: aprilskin-20-vitamin-a-c-e-brightening-serum
# https://incidecoder.com/compare-products/foreo-serum-serum-serum/aprilskin-20-vitamin-a-c-e-brightening-serum
#
# ----------------------------------------------------------------------------------------------------------------------------------
# [ Similarity Measurement ]
# Cosine Similarity - Count-based:  0.303
# Cosine Similarity - Sequence-based(inverse):  0.714
# ----------------------------------------------------------------------------------------------------------------------------------
# [ Ingredients Comparison ]
# Total # of Ingredients: 91
# Total # of Common Ingredients: 16
# Product A # of Unique: 29
# Product B # of Unique: 46
# ----------------------------------------------------------------------------------------------------------------------------------
# [ Common Ingredients ]
#                          ingredient  count used %  \
# 0                   butylene-glycol  24942  32.39
# 1                    1-2-hexanediol  13093   17.0
# 2                   hyaluronic-acid   3496   4.54
# 3                       propanediol  12112  15.73
# 4                ethylhexylglycerin  23514  30.54
# 5                  pentylene-glycol   8601  11.17
# 6   sodium-hyaluronate-crosspolymer   1213   1.58
# 7                             water  67796  88.05
# 8                         panthenol  15715  20.41
# 9                sodium-hyaluronate  19878  25.82
# 10                        adenosine   4362   5.66
# 11                         squalane   7051   9.16
# 12                         glycerin  55954  72.67
# 13       hydrolyzed-hyaluronic-acid   2702   3.51
# 14                      xanthan-gum  22376  29.06
# 15                         pullulan   1228   1.59
#
#                                               effects  \
# 0                ['moisturizer/humectant', 'solvent']
# 1                                         ['solvent']
# 2   ['skin-identical ingredient', 'moisturizer/hum...
# 3                ['solvent', 'moisturizer/humectant']
# 4                                    ['preservative']
# 5                ['solvent', 'moisturizer/humectant']
# 6   ['skin-identical ingredient', 'antioxidant', '...
# 7                                         ['solvent']
# 8               ['soothing', 'moisturizer/humectant']
# 9   ['skin-identical ingredient', 'moisturizer/hum...
# 10                  ['cell-communicating ingredient']
# 11         ['skin-identical ingredient', 'emollient']
# 12  ['skin-identical ingredient', 'moisturizer/hum...
# 13                          ['moisturizer/humectant']
# 14                          ['viscosity controlling']
# 15                                               ['']
#
#                       main effect
# 0           moisturizer/humectant
# 1                         solvent
# 2       skin-identical ingredient
# 3                         solvent
# 4                    preservative
# 5                         solvent
# 6       skin-identical ingredient
# 7                         solvent
# 8                        soothing
# 9       skin-identical ingredient
# 10  cell-communicating ingredient
# 11      skin-identical ingredient
# 12      skin-identical ingredient
# 13          moisturizer/humectant
# 14          viscosity controlling
# 15                            NaN
# ----------------------------------------------------------------------------------------------------------------------------------
# [ Unique Ingredients of foreo-serum-serum-serum ]
#                        ingredient  count used %  \
# 0          peg-ppg-17-6-copolymer    469   0.61
# 1     peg-ppg-14-7-dimethyl-ether    187   0.24
# 2       glyceryl-polymethacrylate    467   0.61
# 3                         betaine   5850    7.6
# 4                          serine   1879   2.44
# 5                         glucose   2331   3.03
# 6              glyceryl-glucoside    469   0.61
# 7                       trehalose   3085   4.01
# 8                        ci-14700    939   1.22
# 9                octyldodeceth-16    225   0.29
# 10                caprylyl-glycol  16992  22.07
# 11                     sodium-pca   4300   5.58
# 12             cyclopentasiloxane   7786  10.11
# 13                triethanolamine   5775    7.5
# 14             acacia-senegal-gum    982   1.28
# 15                           urea   2559   3.32
# 16                   glycereth-26   1634   2.12
# 17  hydrolyzed-glycosaminoglycans    464    0.6
# 18                       carbomer  13247   17.2
# 19          glyceryl-polyacrylate    491   0.64
# 20                          algin    851   1.11
# 21                  benzyl-glycol    350   0.45
# 22                     diglycerin    752   0.98
# 23                        xylitol   2015   2.62
# 24             disodium-phosphate    941   1.22
# 25               propylene-glycol  12806  16.63
# 26            potassium-phosphate    474   0.62
# 27                        gelatin     84   0.11
# 28               raspberry-ketone    310    0.4
#
#                                               effects  \
# 0                            ['emollient', 'solvent']
# 1                                                ['']
# 2                           ['viscosity controlling']
# 3                           ['moisturizer/humectant']
# 4                       ['skin-identical ingredient']
# 5                           ['moisturizer/humectant']
# 6                           ['moisturizer/humectant']
# 7                           ['moisturizer/humectant']
# 8                                        ['colorant']
# 9                                     ['emulsifying']
# 10             ['moisturizer/humectant', 'emollient']
# 11  ['skin-identical ingredient', 'moisturizer/hum...
# 12                           ['emollient', 'solvent']
# 13                                      ['buffering']
# 14                                               ['']
# 15  ['skin-identical ingredient', 'moisturizer/hum...
# 16  ['moisturizer/humectant', 'emollient', 'viscos...
# 17                          ['moisturizer/humectant']
# 18                          ['viscosity controlling']
# 19                                               ['']
# 20                          ['viscosity controlling']
# 21                                        ['solvent']
# 22  ['skin-identical ingredient', 'moisturizer/hum...
# 23                          ['moisturizer/humectant']
# 24                                      ['buffering']
# 25  ['moisturizer/humectant', 'solvent', 'viscosit...
# 26                                      ['buffering']
# 27                          ['viscosity controlling']
# 28                                      ['perfuming']
#
#                   main effect
# 0                   emollient
# 1                         NaN
# 2       viscosity controlling
# 3       moisturizer/humectant
# 4   skin-identical ingredient
# 5       moisturizer/humectant
# 6       moisturizer/humectant
# 7       moisturizer/humectant
# 8                    colorant
# 9                 emulsifying
# 10      moisturizer/humectant
# 11  skin-identical ingredient
# 12                  emollient
# 13                  buffering
# 14                        NaN
# 15  skin-identical ingredient
# 16      moisturizer/humectant
# 17      moisturizer/humectant
# 18      viscosity controlling
# 19                        NaN
# 20      viscosity controlling
# 21                    solvent
# 22  skin-identical ingredient
# 23      moisturizer/humectant
# 24                  buffering
# 25      moisturizer/humectant
# 26                  buffering
# 27      viscosity controlling
# 28                  perfuming
# ----------------------------------------------------------------------------------------------------------------------------------
# [ Unique Ingredients of aprilskin-20-vitamin-a-c-e-brightening-serum ]
#                                   ingredient  count used %  \
# 0                                     silica   7919  10.28
# 1          hemerocallis-fulva-flower-extract     39   0.05
# 2                  dipotassium-glycyrrhizate   3264   4.24
# 3                                   sorbitol   3124   4.06
# 4                          glyceryl-stearate  13648  17.72
# 5                                cholesterol   2340   3.04
# 6                                 tocopherol  22333   29.0
# 7                                beta-glucan   2167   2.81
# 8                           c12-14-pareth-12    326   0.42
# 9                              cellulose-gum   1677   2.18
# 10                          sodium-hydroxide  13457  17.48
# 11                                 bisabolol   3505   4.55
# 12                helianthus-annuus-seed-oil   9738  12.65
# 13                             ascorbic-acid   3745   4.86
# 14              indigofera-tinctoria-extract     17   0.02
# 15                    fructooligosaccharides    701   0.91
# 16             macadamia-ternifolia-seed-oil   1573   2.04
# 17                 sodium-stearoyl-glutamate   1958   2.54
# 18                                   retinal    158   0.21
# 19              caprylic-capric-triglyceride  16504  21.43
# 20                 polyglyceryl-3-distearate    121   0.16
# 21                          sucrose-stearate    623   0.81
# 22                     hydrogenated-lecithin   4373   5.68
# 23                 glyceryl-stearate-citrate   1860   2.42
# 24             sodium-acetylated-hyaluronate   1138   1.48
# 25                                 allantoin  11072  14.38
# 26                         methylpropanediol   2486   3.23
# 27                 ribes-nigrum-leaf-extract     58   0.08
# 28                             madecassoside   1154    1.5
# 29            hydrogenated-poly-c6-14-olefin    515   0.67
# 30                       phenyl-trimethicone   1676   2.18
# 31       citrus-aurantium-bergamia-fruit-oil   1723   2.24
# 32                     rosa-canina-fruit-oil   1525   1.98
# 33  cupressus-sempervirens-leaf-stem-extract     35   0.05
# 34                             disodium-edta  22870   29.7
# 35                             beta-carotene    714   0.93
# 36                   litsea-cubeba-fruit-oil    382    0.5
# 37                               ceramide-np   4155    5.4
# 38                    saccharide-hydrolysate    328   0.43
# 39                      dicaprylyl-carbonate   2656   3.45
# 40                               glutathione    891   1.16
# 41                        tocopheryl-acetate  18802  24.42
# 42               citrus-nobilis-peel-extract     44   0.06
# 43             hydrolyzed-sodium-hyaluronate    862   1.12
# 44                microcrystalline-cellulose    925    1.2
# 45            hedera-helix-leaf-stem-extract    138   0.18
#
#                                               effects  \
# 0                           ['viscosity controlling']
# 1                                                ['']
# 2               ['soothing', 'moisturizer/humectant']
# 3                           ['moisturizer/humectant']
# 4                        ['emollient', 'emulsifying']
# 5          ['skin-identical ingredient', 'emollient']
# 6                                     ['antioxidant']
# 7               ['soothing', 'moisturizer/humectant']
# 8             ['emulsifying', 'surfactant/cleansing']
# 9                           ['viscosity controlling']
# 10                                      ['buffering']
# 11                                       ['soothing']
# 12                                      ['emollient']
# 13   ['antioxidant', 'skin brightening', 'buffering']
# 14                                               ['']
# 15                          ['moisturizer/humectant']
# 16                                      ['emollient']
# 17            ['emulsifying', 'surfactant/cleansing']
# 18                  ['cell-communicating ingredient']
# 19                                      ['emollient']
# 20                                    ['emulsifying']
# 21  ['emollient', 'emulsifying', 'surfactant/clean...
# 22                       ['emollient', 'emulsifying']
# 23                       ['emollient', 'emulsifying']
# 24                          ['moisturizer/humectant']
# 25                                       ['soothing']
# 26                                        ['solvent']
# 27                                      ['perfuming']
# 28                        ['antioxidant', 'soothing']
# 29             ['emollient', 'viscosity controlling']
# 30                                      ['emollient']
# 31                                      ['perfuming']
# 32                                      ['emollient']
# 33                                               ['']
# 34                                      ['chelating']
# 35                                               ['']
# 36                                      ['perfuming']
# 37                      ['skin-identical ingredient']
# 38                          ['moisturizer/humectant']
# 39                                      ['emollient']
# 40                                               ['']
# 41                                    ['antioxidant']
# 42                                      ['perfuming']
# 43                          ['moisturizer/humectant']
# 44                          ['viscosity controlling']
# 45        ['antimicrobial/antibacterial', 'soothing']
#
#                       main effect
# 0           viscosity controlling
# 1                             NaN
# 2                        soothing
# 3           moisturizer/humectant
# 4                       emollient
# 5       skin-identical ingredient
# 6                     antioxidant
# 7                        soothing
# 8                     emulsifying
# 9           viscosity controlling
# 10                      buffering
# 11                       soothing
# 12                      emollient
# 13                    antioxidant
# 14                            NaN
# 15          moisturizer/humectant
# 16                      emollient
# 17                    emulsifying
# 18  cell-communicating ingredient
# 19                      emollient
# 20                    emulsifying
# 21                      emollient
# 22                      emollient
# 23                      emollient
# 24          moisturizer/humectant
# 25                       soothing
# 26                        solvent
# 27                      perfuming
# 28                    antioxidant
# 29                      emollient
# 30                      emollient
# 31                      perfuming
# 32                      emollient
# 33                            NaN
# 34                      chelating
# 35                            NaN
# 36                      perfuming
# 37      skin-identical ingredient
# 38          moisturizer/humectant
# 39                      emollient
# 40                            NaN
# 41                    antioxidant
# 42                      perfuming
# 43          moisturizer/humectant
# 44          viscosity controlling
# 45    antimicrobial/antibacterial
# ==================================================================================================================================

# %%
ing_effect
# Out:
#                                               ingredient  count  used %  \
# 0                                                  water  67796   88.05
# 1                                               glycerin  55954   72.67
# 2                                         phenoxyethanol  36755   47.73
# 3                                                 parfum  36094   46.88
# 4                                        butylene-glycol  24942   32.39
# ...                                                  ...    ...     ...
# 15181  lactobacillus-pueraria-mirifica-root-ferment-f...      1    0.00
# 15182  aspergillus-saccharomyces-pumpkin-seed-ferment...      1    0.00
# 15183  saccharomyces-prunus-mume-extract-ferment-filt...      1    0.00
# 15184  saccharomyces-day-lily-flower-honey-ferment-fi...      1    0.00
# 15185  aspergillus-saccharomyces-glycyrrhiza-uralensi...      1    0.00
#
#                                                  effects  \
# 0                                            ['solvent']
# 1      ['skin-identical ingredient', 'moisturizer/hum...
# 2                                       ['preservative']
# 3                                          ['perfuming']
# 4                   ['moisturizer/humectant', 'solvent']
# ...                                                  ...
# 15181                                               ['']
# 15182                                               ['']
# 15183                          ['moisturizer/humectant']
# 15184                                               ['']
# 15185                                               ['']
#
#                      main effect
# 0                        solvent
# 1      skin-identical ingredient
# 2                   preservative
# 3                      perfuming
# 4          moisturizer/humectant
# ...                          ...
# 15181                        NaN
# 15182                        NaN
# 15183      moisturizer/humectant
# 15184                        NaN
# 15185                        NaN
#
# [15186 rows x 5 columns]
